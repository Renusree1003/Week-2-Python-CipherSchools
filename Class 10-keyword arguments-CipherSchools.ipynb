# %%
def hello():
    return 1
hello
# Out:
# <function __main__.hello()>

# %%
hello()
# Out:
# 1

# %%
a = 1
a = hello
a()
# Out:
# 1

# %%
def func(a, b, c):
    print(a)
    print(b)
    print(c)
func(c = 1, a = 2, b = 3)
# Out:
# 2
# 3
# 1

# %%
print(1, 2, 3, 4, 5, sep = ",")
# Out:
# 1,2,3,4,5

# %%
def func(a, b):
    print(a, b)
func(1, 2)
# Out:
# 1 2

# %%
def func(a = 1, b = 2):
    print(a, b)
func()
func(1)
func(3, 4)
# Out:
# 1 2
# 1 2
# 3 4

# %%
def func(a, b, *c, d):
    print(a)
    print(b)
    print(c)
    print(d)
func(1, 2, 3, 4, 5, 6, 7, d = 8)
# Out:
# 1
# 2
# (3, 4, 5, 6, 7)
# 8

# %%
def func(a, b, *c, d, e = "renu"):
    print(a)
    print(b)
    print(c)
    print(d)
    print(e)
func(1, 2, 3, 4, d = "something", e = "asdf")
# Out:
# 1
# 2
# (3, 4)
# something
# asdf
