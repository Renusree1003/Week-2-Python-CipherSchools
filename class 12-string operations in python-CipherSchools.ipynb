# %%
a = 5
print("value of a is %d" % (a))
print("value of a is{}" .format(a))
# Out:
# value of a is 5
# value of a is5

# %%
" renu  ".strip()
# Out:
# 'renu'

# %%
"1, 2, 3, 4, 5".split(",")
# Out:
# ['1', ' 2', ' 3', ' 4', ' 5']

# %%
"renu sree".replace("n", "s")
# Out:
# 'resu sree'

# %%
a, b, c, d = 1, 2, 3, 4
"a = {2}, b = {1}, c ={0}".format(c, b, a)
# Out:
# 'a = 1, b = 2, c =3'

# %%
name = "renu sree"
company = "shuttl"
"name = {name} company = {company}".format(name = name, company = company)
# Out:
# 'name = renu sree company = shuttl'

# %%
print(f"name = {name}")
# Out:
# name = renu sree

# %%
len(r"a\nb")
# Out:
# 4

# %%
for c in r"a\nb":
    print(c)
# Out:
# a
# \
# n
# b
